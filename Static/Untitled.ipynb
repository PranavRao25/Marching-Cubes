# %%
import skimage

# %%
im = skimage.io.imread('army.jpg',as_gray=True)

# %%
skimage.io.imshow(im)

# %%
l = list(im)

# %%
len(l[::])
# Out:
# 186

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
sin = lambda x: np.sin(x)

# %%
q = 2

# %%
plt.plot(list(range(q)),sin(list(range(q))))
plt.savefig('sin.jpg')

# %%
import skimage

im = skimage.io.imread("army.jpg",as_gray=True)
for i in range(im.shape[0]):
    s = ""
    for j in range(im.shape[1]):
        s += f"{im[i][j]} "
    print(s)

# %%
img = list(im)

# %%
l = []
for i in img:
    if(len(i) not in l):
        l.append(len(i))
print(max(l))
# Out:
# 98

# %%
print(l)
# Out:
# [98]

# %%
grid=[]

# %%
with open("h.txt","r") as file:
        lines = file.readlines()
        cols = len(lines)
        l = []
        for i in lines:
            s = [float(j) for j in i.split()]
            if(len(s) not in l):
                l.append(len(i))
            grid.append(s)
        rows = max(l)

# %%
print(rows)
print(l)
# Out:
# 1921
# [1904, 1921, 1872, 1903, 1880, 1904, 1890, 1851, 1863, 1890, 1861, 1851, 1853, 1843, 1869, 1864, 1836, 1807, 1830, 1856, 1849, 1779, 1813, 1828, 1791, 1798, 1732, 1720, 1783, 1788, 1827, 1823, 1843, 1867, 1731, 1777, 1844, 1823, 1804, 1860, 1852, 1824, 1857, 1806, 1819, 1801, 1860, 1806, 1793, 1776, 1790, 1852, 1822, 1841, 1833, 1819, 1831, 1844, 1798, 1795, 1813, 1831, 1810, 1844, 1779, 1791, 1801, 1777, 1858, 1840, 1822, 1825, 1813, 1781, 1755, 1776, 1828, 1801, 1779, 1883, 1807, 1877, 1842, 1792, 1890, 1815, 1857, 1843, 1838, 1888, 1831, 1860, 1834, 1848, 1838, 1869, 1862, 1838, 1681, 1787, 1837, 1806, 1773, 1836, 1784, 1826, 1831]
